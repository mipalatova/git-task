# %% [markdown]
# # Знакомство с SymPy

# %% [markdown]
# ### Индивидуальное домашнее задание

# %% [markdown]
# ### Палатова Мария Игоревна (pmi004), группа: М22-117

# %% [markdown]
# **Выполните указанные ниже действия, сохраните свою работу в виде ipynb-файла с именем `pmi004_hw00_22.ipynb` и прикрепите этот файл к сообщению своему преподавателю**.

# %% [markdown]
# **Задание 1.** Вычислите значение выражения $\displaystyle\lg\left(\frac{\sqrt{\sqrt2}}{{(\pi-e)}^3{(4+\sqrt2)}^5}+\sqrt[7]{5^3}\right)$ с точностью 40 значащих десятичных цифр.

# %%
from sympy import *
log(sqrt(sqrt(2))/(pi-E)**3/(4+sqrt(2))**5+root(5**3,7),10).evalf(40)
# Out:
# 0.3002921767073998496272729457339827396056

# %% [markdown]
# **Задание 2.** Раскройте скобки в выражении $\left(u + z\right)^{3} \left(x - 2 y\right) \left(x + 2 y\right)^{3}$.

# %%
var('u z x y')
expand((u+z)**3*(x-2*y)*(x+2*y)**3)
# Out:
# u**3*x**4 + 4*u**3*x**3*y - 16*u**3*x*y**3 - 16*u**3*y**4 + 3*u**2*x**4*z + 12*u**2*x**3*y*z - 48*u**2*x*y**3*z - 48*u**2*y**4*z + 3*u*x**4*z**2 + 12*u*x**3*y*z**2 - 48*u*x*y**3*z**2 - 48*u*y**4*z**2 + x**4*z**3 + 4*x**3*y*z**3 - 16*x*y**3*z**3 - 16*y**4*z**3

# %% [markdown]
# **Задание 3.** Разложите на множители многочлен $2 u^{3} x^{3} - 9 u^{3} x^{2} y + 12 u^{3} x y^{2} - 4 u^{3} y^{3} - 12 u^{2} x^{3} z + 54 u^{2} x^{2} y z - 72 u^{2} x y^{2} z + 24 u^{2} y^{3} z + 24 u x^{3} z^{2} - 108 u x^{2} y z^{2} + 144 u x y^{2} z^{2} - 48 u y^{3} z^{2} - 16 x^{3} z^{3} + 72 x^{2} y z^{3} - 96 x y^{2} z^{3} + 32 y^{3} z^{3}$.

# %%
factor(2*u**3*x**3 - 9*u**3*x**2*y + 12*u**3*x*y**2 - 4*u**3*y**3 - 12*u**2*x**3*z + 54*u**2*x**2*y*z - 72*u**2*x*y**2*z + 24*u**2*y**3*z + 24*u*x**3*z**2 - 108*u*x**2*y*z**2 + 144*u*x*y**2*z**2 - 48*u*y**3*z**2 - 16*x**3*z**3 + 72*x**2*y*z**3 - 96*x*y**2*z**3 + 32*y**3*z**3)
# Out:
# -(-u + 2*z)**3*(x - 2*y)**2*(2*x - y)

# %% [markdown]
# **Задание 4.** Найдите все (включая комплексные) корни уравнения $20 x^{4} + 39 x^{3} + 137 x^{2} - 9 x - 7 = 0$.

# %%
solveset(20*x**4 + 39*x**3 + 137*x**2 - 9*x - 7, x)
# Out:
# FiniteSet(-1/5, 1/4, -1 + sqrt(6)*I, -1 - sqrt(6)*I)

# %% [markdown]
# **Задание 5.** Постройте график функции, заданной неявно: $\displaystyle x^{\frac{2}{3}} + y^{\frac{2}{3}} - \frac{16}{3}=0$. Используйте одинаковый масштаб по координатным осям.

# %%
plot_implicit(root(x**2,3)+root(y**2,3)-16/3, (x, -13, 13), (y, -13, 13), aspect_ratio = (1,1))

# %% [markdown]
# **Задание 6.** Постройте график функции, заданной параметрически: $\displaystyle x(t)=3 \sin{\left(5 t \right)}$, $\displaystyle y(t)=3 \sin{\left(4 t \right)}$. Используйте минимальный по длине промежуток изменения параметра и одинаковый масштаб по координатным осям.

# %%
var('t')
plotting.plot_parametric(3*sin(5*t), 3*sin(4*t), (t, 0, 2*pi), aspect_ratio = (1,1))
